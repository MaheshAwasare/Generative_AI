# %% [markdown]
# <h1>Gaussian (Normal) Distribution</h1>
#
# Intuition:  Think of it as the "Goldilocks" of distributions—it's just right for many real-world phenomena that cluster around an average value, like heights, IQ scores, or exam grades.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Following code generates 1000 samples from a normal distribution with mean 50 and standard deviation 10
samples = np.random.normal(loc=50, scale=10, size=1000)

# Plot it
plt.hist(samples, bins=40, edgecolor='black')
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Gaussian Distribution")
plt.show()

# %% [markdown]
# <h1>Poisson Distribution</h1>
#
# <p> Intuition:  It's the "rare events" distribution, useful for modeling the number of occurrences of events that happen infrequently and independently, like website visits per hour or customer arrivals at a store.</p>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Following code generates 100 samples from a Poisson distribution with a mean of 4
samples = np.random.poisson(lam=4, size=100)

#plot it!
plt.hist(samples, bins=range(max(samples) + 2), edgecolor='black')
plt.xlabel("Number of occurrences")
plt.ylabel("Frequency")
plt.title("Poisson Distribution")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Sample data using nose and eyes co-ordinates
eye_x = np.random.normal(loc=70, scale=10, size=100)  
eye_y = np.random.normal(loc=50, scale=5, size=100) 
nose_y = np.random.normal(loc=20, scale=8, size=100)  
nose_x = np.random.normal(loc=70, scale=5, size=100)  

# Plot the distributions
plt.figure(figsize=(8, 5))
plt.scatter(eye_x, eye_y, label='Eyes')
plt.scatter(nose_x, nose_y, label='Noses')
plt.xlabel("Horizontal Position")
plt.ylabel("Vertical Position")
plt.title("Distributions of Eye and Nose Positions")
plt.legend()
plt.show()

# %%
import numpy as np

# Define your distributions
eye_x_dist = np.random.normal(loc=70, scale=10, size=100)
eye_y_dist = np.random.normal(loc=50, scale=5, size=100)
nose_x_dist = np.random.normal(loc=70, scale=5, size=100)
nose_y_dist = np.random.normal(loc=20, scale=8, size=100)

# Generate random indices to sample from each distribution
indices = np.random.randint(0, len(eye_x_dist), size=10)

# Sample eye and nose points based on the chosen indices
eye_x_points = eye_x_dist[indices]
eye_y_points = eye_y_dist[indices]
nose_x_points = nose_x_dist[indices]
nose_y_points = nose_y_dist[indices]

# Print the generated eye-nose point combinations
for i in range(len(indices)):
    print(f"Eye ({eye_x_points[i]}, {eye_y_points[i]}) - Nose ({nose_x_points[i]}, {nose_y_points[i]})")
# Out:
# Eye (68.19492415689342, 53.121617578387045) - Nose (69.86914313315708, 4.255380505071114)
# Eye (74.47251504647217, 47.78078869783922) - Nose (69.91234049466505, 24.037471452421315)
# Eye (79.78525304988194, 52.80243749489113) - Nose (64.84732711914842, 36.028228089153615)
# Eye (75.35874380552778, 42.35322376426204) - Nose (69.00261724773264, 20.467013253158182)
# Eye (56.00690908708275, 58.39599564272828) - Nose (71.67393995217347, 19.607617319890828)
# Eye (62.71622960373409, 47.34235494419205) - Nose (68.28748460758909, 21.8269780811902)
# Eye (53.29216426939227, 50.58713715914625) - Nose (61.34306527678255, 19.47740028131948)
# Eye (61.25283585393035, 48.0896142493122) - Nose (75.2136411573146, 12.187708500680191)
# Eye (51.850758431991544, 45.406818313840596) - Nose (67.21650555580268, 2.5185643783519254)
# Eye (75.4649551435899, 57.739050550778856) - Nose (73.1299307397505, 13.572259060999391)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define your distributions
eye_x_dist = np.random.normal(loc=70, scale=10, size=100)
eye_y_dist = np.random.normal(loc=50, scale=5, size=100)
nose_x_dist = np.random.normal(loc=70, scale=5, size=100)
nose_y_dist = np.random.normal(loc=20, scale=8, size=100)

# Generate random indices to sample from each distribution
indices = np.random.randint(0, len(eye_x_dist), size=10)

# Sample eye and nose points based on the chosen indices
eye_x_points = eye_x_dist[indices]
eye_y_points = eye_y_dist[indices]
nose_x_points = nose_x_dist[indices]
nose_y_points = nose_y_dist[indices]

# Plot the distributions
plt.figure(figsize=(10, 6))

# Subplots for individual distributions
plt.subplot(221)
plt.hist(eye_x_dist, bins=20, edgecolor='black', label='Eye X')
plt.xlabel("Horizontal Position")
plt.ylabel("Frequency")
plt.title("Eye X Distribution")
plt.legend()

plt.subplot(222)
plt.hist(eye_y_dist, bins=20, edgecolor='black', label='Eye Y')
plt.xlabel("Vertical Position")
plt.ylabel("Frequency")
plt.title("Eye Y Distribution")
plt.legend()

plt.subplot(223)
plt.hist(nose_x_dist, bins=20, edgecolor='black', label='Nose X')
plt.xlabel("Horizontal Position")
plt.ylabel("Frequency")
plt.title("Nose X Distribution")
plt.legend()

plt.subplot(224)
plt.hist(nose_y_dist, bins=20, edgecolor='black', label='Nose Y')
plt.xlabel("Vertical Position")
plt.ylabel("Frequency")
plt.title("Nose Y Distribution")
plt.legend()

# Plot sampled points on main figure
plt.figure(figsize=(8, 5))
plt.scatter(eye_x_points, eye_y_points, label='Eyes', marker='o', color='blue')
plt.scatter(nose_x_points, nose_y_points, label='Noses', marker='^', color='red')
plt.xlabel("Horizontal Position")
plt.ylabel("Vertical Position")
plt.title("Sampled Eye and Nose Points")
plt.legend()

plt.tight_layout()  # Adjusts space between subplots
plt.show()

# Print the generated eye-nose point combinations
for i in range(len(indices)):
    print(f"Eye ({eye_x_points[i]}, {eye_y_points[i]}) - Nose ({nose_x_points[i]}, {nose_y_points[i]})")
# Out:
# Eye (69.58053018921125, 52.53290651759241) - Nose (68.75133689843166, 34.13059865810658)
# Eye (60.29073383958337, 53.51486335015106) - Nose (72.88398410401268, 10.895358690943588)
# Eye (76.33006307290096, 51.67976020455273) - Nose (59.42421758618764, 23.44471696270201)
# Eye (73.7746533082019, 52.86525589936112) - Nose (69.88865290247976, 16.921331410352696)
# Eye (67.74398042291651, 55.45863692305426) - Nose (70.86035847371114, 28.192904985959974)
# Eye (75.03523950135747, 46.24273562051823) - Nose (68.1035866086671, 23.367955659347075)
# Eye (80.5249678682795, 57.15955277570947) - Nose (61.15066185810986, 4.797497666183704)
# Eye (64.57888617071629, 47.44704373733858) - Nose (78.74664729418615, 14.961664825247107)
# Eye (56.3743335710625, 44.42567451239298) - Nose (69.78970589456867, 17.739814265203524)
# Eye (65.93042813301835, 62.21261767966662) - Nose (71.41975079248819, 13.920685679393697)
